# %% [markdown]
# Note: copied and modified from "Presentation_042123.ipynb" in ./ztrax_FL/DataViz

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# from matplotlib.transforms import ScaledTranslation
# import matplotlib.pyplot as plt

# x = ["Irma", "Sandy", "Ivan"]
# y1 = [-0.09, -0.09, -0.10]
# yerr1 = [0.29, 0.29, 0.27]
# y2 = [-0.08, -0.07, -0.06]
# yerr2 = [0.37, 0.42, 0.44]
# y3 = [-0.08, -0.07, -0.06]
# yerr3 = [0.7, 0.42, 0.44]

# fig, ax = plt.subplots(figsize=(7.5, 5))

# trans1 = ax.transData + ScaledTranslation(-5/72, 0, fig.dpi_scale_trans)
# trans2 = ax.transData + ScaledTranslation(+5/72, 0, fig.dpi_scale_trans)
# trans3 = ax.transData + ScaledTranslation(+15/72, 0, fig.dpi_scale_trans)

# er1 = ax.errorbar(x, y1, yerr=yerr1, color='#8B0000', marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans1, label="Near Term")
# er2 = ax.errorbar(x, y2, yerr=yerr2, color='#9ACD32', marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans2, label="Medium Term")
# er3 = ax.errorbar(x, y3, yerr=yerr3, color='#1E90FF', marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans3, label="Long Term")

# plt.legend(bbox_to_anchor=(1.35, 1))
# plt.xlabel("Hurricanes", fontweight='bold', fontsize=11)
# plt.ylabel("Marginal effect on lending frequency", fontweight='bold', fontsize=11)
# plt.axhline(0, linestyle='--', color='#9FB6CD')

# plt.savefig('margin2_poster.png', bbox_inches='tight', dpi=1200)

# plt.show()

# %% [markdown]
# - overall effect (main + interaction)

# %%
from matplotlib.transforms import ScaledTranslation
# import matplotlib.pyplot as plt
#Stat do file name: Main_flood_041823 +  Main_flood_041823B +  Main_flood_041823C
# 'high/mid risk-graph' in Google sheet: https://docs.google.com/spreadsheets/d/1Dgo2fl6EPmOkbYvh88HKo-8EdSprJ_s-zEJZL1_5_eQ/edit?gid=1919187245#gid=1919187245

colors = plt.cm.Greens_r([0.4, 0.2, 0.7])

x = ["IVAN", "SANDY", "IRMA"]

y1 = [-0.3835247,		-0.4216141,		-0.4862302]
yerr1 = [0.3418369,		0.3420483,		0.3528486]
y2 = [-0.381013,		-0.4284454,		-0.4899461]
yerr2 = [0.3198346,		0.3200753,		0.3313748]

y3 = [-0.3759897,		-0.442108,		-0.4973779]
yerr3 = [0.4242217,		0.4245,		0.4336997]

fig, ax = plt.subplots(figsize=(7.5, 5))

trans1 = ax.transData + ScaledTranslation(-100/1000, 0, fig.dpi_scale_trans)
trans2 = ax.transData + ScaledTranslation(+50/1000, 0, fig.dpi_scale_trans)
trans3 = ax.transData + ScaledTranslation(+200/1000, 0, fig.dpi_scale_trans)

er1 = ax.errorbar(x, y1, yerr=yerr1, color=colors[1], marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans1, label="Near Mangrove")
er1[-1][0].set_alpha(0.5)  # set the alpha of the error bar lines

er2 = ax.errorbar(x, y2, yerr=yerr2, color=colors[0], marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans2, label="2km+")
er2[-1][0].set_alpha(0.5)  # set the alpha of the error bar lines

er3 = ax.errorbar(x, y3, yerr=yerr3, color=colors[2], marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans3, label="4km+")
# er3[-1][0].set_alpha(0.5)  # set the alpha of the error bar lines

plt.legend(bbox_to_anchor=(1.35, 1))
plt.xlabel("Hurricanes", fontweight='bold', fontsize=11)
plt.ylabel("House Price (log)", fontweight='bold', fontsize=11)
# plt.axhline(0, linestyle='--', color='#9FB6CD')

plt.savefig('../../Results/Figures/highrisk-graph.png', bbox_inches='tight', dpi=1200)

plt.show()

# %% [markdown]
# - overall effect (main + interaction)

# %%
from matplotlib.transforms import ScaledTranslation
# import matplotlib.pyplot as plt
#Stat do file name: Main_flood_041823 +  Main_flood_041823B +  Main_flood_041823C
# 'high/mid risk-graph' in Google sheet

colors = plt.cm.Greens_r([0.4, 0.2, 0.7])

x = ["IVAN", "SANDY", "IRMA"]

y1 = [-0.3184238,		-0.3661489,		-0.205742]
yerr1 = [0.2920775,		0.292427,		0.3051072]

y2 = [-0.4658925,		-0.4879778,		-0.3942846]
yerr2 = [0.2948145,		0.2951155,		0.3073708]

y3 = [-0.7608299,		-0.7316356,		-0.7713697]
yerr3 = [0.3746421,		0.3748394,		0.3843406]

fig, ax = plt.subplots(figsize=(7.5, 5))

trans1 = ax.transData + ScaledTranslation(-100/1000, 0, fig.dpi_scale_trans)
trans2 = ax.transData + ScaledTranslation(+50/1000, 0, fig.dpi_scale_trans)
trans3 = ax.transData + ScaledTranslation(+200/1000, 0, fig.dpi_scale_trans)

er1 = ax.errorbar(x, y1, yerr=yerr1, color=colors[1], marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans1, label="Near Mangrove")
er1[-1][0].set_alpha(0.5)  # set the alpha of the error bar lines

er2 = ax.errorbar(x, y2, yerr=yerr2, color=colors[0], marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans2, label="2km+")
er2[-1][0].set_alpha(0.5)  # set the alpha of the error bar lines

er3 = ax.errorbar(x, y3, yerr=yerr3, color=colors[2], marker="o", markersize='8', elinewidth=3, linestyle="none", transform=trans3, label="4km+")
# er3[-1][0].set_alpha(0.5)  # set the alpha of the error bar lines

plt.legend(bbox_to_anchor=(1.35, 1))
plt.xlabel("Hurricanes", fontweight='bold', fontsize=11)
plt.ylabel("House Price (log)", fontweight='bold', fontsize=11)
# plt.axhline(0, linestyle='--', color='#9FB6CD')

plt.savefig('../../Results/Figures/midrisk-graph.png', bbox_inches='tight', dpi=500)

plt.show()

# %%
from matplotlib.transforms import ScaledTranslation
import matplotlib.pyplot as plt

# keep 3 colors (we still plot 3 series)
colors = plt.cm.Greens_r([0.4, 0.2, 0.7])

# 2 groups only
x = ["Mid Risk-1 year after", "High Risk-1 year after", "Mid Risk-2-3 year after", "High Risk-2-3 year after"]

# near mangrove, 2km+, and 4km+
y1    = [-0.0147749	,	0.0015217	,	-0.0178075	,	-0.0414806]
yerr1 = [ 0.0061891	,	0.0065645	,	0.0062195	,	0.0070556]

y2    = [-0.0295498	,	0.0030433	,	-0.035615	,	-0.0829612]
yerr2 = [ 0.0123783	,	0.013129	,	0.012439	,	0.0141112]

y3    = [-0.0590997	,	0.0060866	,	-0.0712299	,	-0.1659224]
yerr3 = [0.0247566	,	0.0262581	,	0.024878	,	0.0282225]

fig, ax = plt.subplots(figsize=(7.5, 5))

# same small horizontal nudges for the 3 series
trans1 = ax.transData + ScaledTranslation(-100/1000, 0, fig.dpi_scale_trans)
trans2 = ax.transData + ScaledTranslation(+50/1000,  0, fig.dpi_scale_trans)
trans3 = ax.transData + ScaledTranslation(+200/1000, 0, fig.dpi_scale_trans)

er1 = ax.errorbar(x, y1, yerr=yerr1, color=colors[1], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans1, label="Near Mangrove")
er1[-1][0].set_alpha(0.5)

er2 = ax.errorbar(x, y2, yerr=yerr2, color=colors[0], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans2, label="2km+")
er2[-1][0].set_alpha(0.5)

er3 = ax.errorbar(x, y3, yerr=yerr3, color=colors[2], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans3, label="4km+")

plt.legend(bbox_to_anchor=(1.35, 1))
plt.xlabel("Flood Zone X Hurricane", fontweight='bold', fontsize=11)
plt.ylabel("House Price (log)", fontweight='bold', fontsize=11)

plt.savefig('../../Results/Figures/benchmark-floodrisk.png', bbox_inches='tight', dpi=500)
plt.show()

# %%
from matplotlib.transforms import ScaledTranslation
import matplotlib.pyplot as plt

# keep 3 colors (we still plot 3 series)
colors = plt.cm.Greens_r([0.4, 0.2, 0.7])

# 2 groups only
x = [
    "Low Risk-1 year", "Mid Risk-1 year", "High Risk-1 year",
    "Low Risk-2-3 years", "Mid Risk-2-3 years", "High Risk-2-3 years"
]
# near mangrove, 2km+, and 4km+
y1    = [0.0005698	,	-0.0147749	,	0.0015217	,	-0.0130041	,	-0.0178075	,	-0.0414806]
yerr1 = [0.0100902	,	0.0061891	,	0.0065645	,	0.0054258	,	0.0062195	,	0.0070556]

y2    = [0.0011396	,	-0.0295498	,	0.0030433	,	-0.0260081	,	-0.035615	,	-0.0829612]
yerr2 = [ 0.0201809	,	0.0123783	,	0.013129	,	0.0108515	,	0.012439	,	0.0141112]

y3    = [0.0022793	,	-0.0590997	,	0.0060866	,	-0.0520163	,	-0.0712299	,	-0.1659224]
yerr3 = [0.0403617	,	0.0247566	,	0.0262581	,	0.0217031	,	0.024878	,	0.0282225]

fig, ax = plt.subplots(figsize=(7.5, 5))

# same small horizontal nudges for the 3 series
trans1 = ax.transData + ScaledTranslation(-100/1000, 0, fig.dpi_scale_trans)
trans2 = ax.transData + ScaledTranslation(+50/1000,  0, fig.dpi_scale_trans)
trans3 = ax.transData + ScaledTranslation(+200/1000, 0, fig.dpi_scale_trans)

er1 = ax.errorbar(x, y1, yerr=yerr1, color=colors[1], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans1, label="Near Mangrove")
er1[-1][0].set_alpha(0.5)

er2 = ax.errorbar(x, y2, yerr=yerr2, color=colors[0], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans2, label="2km+")
er2[-1][0].set_alpha(0.5)

er3 = ax.errorbar(x, y3, yerr=yerr3, color=colors[2], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans3, label="4km+")

plt.xticks(rotation=30, ha="right")  # Tilt x-axis labels
ax.tick_params(axis='x', labelsize=9)  # Smaller font for x-axis labels
ax.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

# Add vertical separator after "High Risk-1 year"
ax.axvline(x=2.5, color='black', linestyle='--', linewidth=1)  # Between 3rd and 4th label

# Optional: add group labels
ax.text(1, ax.get_ylim()[1]*1.05, "1 Year", ha='center', fontweight='bold')
ax.text(4, ax.get_ylim()[1]*1.05, "2–3 Years", ha='center', fontweight='bold')

plt.legend(bbox_to_anchor=(1.35, 1))
plt.xlabel("Flood Zone X Hurricane", fontweight='bold', fontsize=11)
plt.ylabel("House Price (log)", fontweight='bold', fontsize=11)

plt.savefig('../../Results/Figures/benchmark-floodrisk-all.png', bbox_inches='tight', dpi=500)
plt.show()

# %%
from matplotlib.transforms import ScaledTranslation
import matplotlib.pyplot as plt

# keep 3 colors (we still plot 3 series)
colors = plt.cm.Greens_r([0.4, 0.2, 0.7])

# 2 groups only
x = [
    "Low Risk-1 year", "Mid Risk-1 year", "High Risk-1 year"
]
# near mangrove, 2km+, and 4km+
y1    = [0.0005698	,	-0.0147749	,	0.0015217]
yerr1 = [0.0100902	,	0.0061891	,	0.0065645]

y2    = [0.0011396	,	-0.0295498	,	0.0030433]
yerr2 = [ 0.0201809	,	0.0123783	,	0.013129]

y3    = [0.0022793	,	-0.0590997	,	0.0060866]
yerr3 = [0.0403617	,	0.0247566	,	0.0262581]

fig, ax = plt.subplots(figsize=(7.5, 5))

# same small horizontal nudges for the 3 series
# trans1 = ax.transData + ScaledTranslation(-100/1000, 0, fig.dpi_scale_trans)
# trans2 = ax.transData + ScaledTranslation(+50/1000,  0, fig.dpi_scale_trans)
# trans3 = ax.transData + ScaledTranslation(+200/1000, 0, fig.dpi_scale_trans)
trans1 = ax.transData + ScaledTranslation(-150/1000, 0, fig.dpi_scale_trans)
trans2 = ax.transData + ScaledTranslation(0/1000,   0, fig.dpi_scale_trans)
trans3 = ax.transData + ScaledTranslation(+200/1000, 0, fig.dpi_scale_trans)
ax.margins(x=0.2)  # adds 20% padding on both sides of x-axis

er1 = ax.errorbar(x, y1, yerr=yerr1, color=colors[1], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans1, label="Near Mangrove")
er1[-1][0].set_alpha(0.5)

er2 = ax.errorbar(x, y2, yerr=yerr2, color=colors[0], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans2, label="2km+")
er2[-1][0].set_alpha(0.5)

er3 = ax.errorbar(x, y3, yerr=yerr3, color=colors[2], marker="o", markersize=8,
                  elinewidth=3, linestyle="none", transform=trans3, label="4km+")

plt.xticks(rotation=0, ha="center")  # Tilt x-axis labels
ax.tick_params(axis='x', length=0)  # removes the short vertical ticks
ax.tick_params(axis='x', labelsize=12)  # Smaller font for x-axis labels
# ax.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

# Add vertical separators between categories
for xpos in [0.5, 1.5]:
    ax.axvline(x=xpos, color='lightgray', linestyle='-', linewidth=1)

# Horizontal dashed line at 0
ax.axhline(y=0, color='gray', linestyle='--', linewidth=1)

plt.legend(bbox_to_anchor=(1.35, 1))
plt.xlabel("Flood Zone X Hurricane", fontweight='bold', fontsize=11)
plt.ylabel("House Price (log)", fontweight='bold', fontsize=11)

plt.savefig('../../Results/Figures/benchmark-floodrisk-1styear.png', bbox_inches='tight', dpi=500)
plt.show()
